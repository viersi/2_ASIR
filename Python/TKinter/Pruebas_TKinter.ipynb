# %%
from tkinter import *
root = Tk()
frm = ttk.Frame(root, padding=10)
frm.grid()
Label(frm, text="Calculadora Papá", font=('Times New Roman', 16)).grid(column=0, row=0)
Button(frm, text="1", font=('Times New Roman', 16), command=root.destroy).grid(column=0, row=1)
Button(frm, text="2", font=('Times New Roman', 16), command=root.destroy).grid(column=1, row=1)
Button(frm, text="3", font=('Times New Roman', 16), command=root.destroy).grid(column=2, row=1)
Button(frm, text="4", font=('Times New Roman', 16), command=root.destroy).grid(column=0, row=2)
Button(frm, text="5", font=('Times New Roman', 16), command=root.destroy).grid(column=1, row=2)
Button(frm, text="6", font=('Times New Roman', 16), command=root.destroy).grid(column=2, row=2)
Button(frm, text="7", font=('Times New Roman', 16), command=root.destroy).grid(column=0, row=3)
Button(frm, text="8", font=('Times New Roman', 16), command=root.destroy).grid(column=1, row=3)
Button(frm, text="9", font=('Times New Roman', 16), command=root.destroy).grid(column=2, row=3)
Button(frm, text="0", font=('Times New Roman', 16), command=root.destroy).grid(column=1, row=4)
Button(frm, text="+", font=('Times New Roman', 16), command=root.destroy).grid(column=0, row=5)
Button(frm, text="-", font=('Times New Roman', 16), command=root.destroy).grid(column=1, row=5)
Button(frm, text="=", font=('Times New Roman', 16), command=root.destroy).grid(column=2, row=5)
root.mainloop()

# %%
root = Tk()
root.title("Escritura en tiempo real")
frm = ttk.Frame(root, padding=10)
frm.grid()
