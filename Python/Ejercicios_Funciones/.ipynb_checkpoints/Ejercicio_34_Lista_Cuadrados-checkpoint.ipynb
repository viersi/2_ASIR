# %%
#Recibe una lista y devuelve una lista con sus cuadrados.
def ft_sqlist(x):
    list = []
#Recorremos la lista y almacenamos el cuadrado de cada elemento en una nueva lista.
    for i in x:
        list = list + [(i**2)]
    return(list)
    
ft_sqlist([3, 7, 2, 9, 4])
# Out:
# [9, 49, 4, 81, 16]
