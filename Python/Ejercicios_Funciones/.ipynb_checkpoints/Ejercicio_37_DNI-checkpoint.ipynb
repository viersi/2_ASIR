# %%
def ft_letradni(x):
    pool = ["T", "R", "W", "A", "G", "M", "Y", "F", "P", "D", "X", "B", "N", "J", "Z", "S", "Q", "V", "H", "L", "C", "K", "E"]
    resto = x % 23
    return(pool[resto])

ft_letradni(54037169)
# Out:
# 'A'
