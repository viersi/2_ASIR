# %%
def ft_find(x, y):
    counter = 0
    for i in x:
        if i == y:
            counter += 1

    return(counter)

ft_find("En el principio, los dioses forjaron los cielos y la tierra, y de la espuma del mar nació la primera criatura inmortal.", "a")
# Out:
# 12
