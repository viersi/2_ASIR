# %%
def ft_valid_date(d, m, y):
    bis = False
    if y % 4 == 0:
        bis = True
    
    if m < 1 and m > 12:
        return(False)
    if y < 1:
        return(False)
    if d < 1:
        return(False)
