# %%
#Simula un lanzamiento de dado, devuelve un numero aleatorio entre 1 y 6.
#Importamos la libreria random.
import random
#La funcion usa el metodo randint para generar un aleatorio entre 1 y 6, lo almacenamos en la variable num y devolvemos num.
def ft_dice():
    num = random.randint(1, 6)
    return(num)

ft_dice()
# Out:
# 6
