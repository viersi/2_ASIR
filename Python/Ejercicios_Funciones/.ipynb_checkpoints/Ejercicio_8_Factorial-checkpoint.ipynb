# %%
#Recibe un numero y devulve su factorial.
def ft_factorial(x):
    result = 1
#Multiplicamos todos los numeros desde 1 hasta el introducido y vamos acumulando su valor en la variable resultado.
    for i in range(1, x + 1):
        result = result * i
    return(result)

ft_factorial(5)
# Out:
# 120
