# %%
#Crea un diccionario llamado `persona` con tu nombre, edad y ciudad. 
#Muestra cada valor por pantalla.
persona = {
    "Nombre": "Víctor",
    "Edad": 25,
    "Ciudad": "Leganés"
}

print(persona)
# Out:
# {'Nombre': 'Víctor', 'Edad': 25, 'Ciudad': 'Leganés'}

# %%
#Añade una nueva clave `profesión` al diccionario anterior y muestra el resultado.
persona["profesión"] = "informático"

print(persona)
# Out:
# {'Nombre': 'Víctor', 'Edad': 25, 'Ciudad': 'Leganés', 'profesión': 'informático'}

# %%
#Crea un diccionario `capitales` con 3 países y sus capitales. Muestra solo las claves.
capitales = {
    "España": "Madrid",
    "Bulgaria": "Sofia",
    "Macedonia del norte": "Skopje"
}

print(capitales.keys())

for i in capitales.keys():
    print(i)
# Out:
# dict_keys(['España', 'Bulgaria', 'Macedonia del norte'])
# España
# Bulgaria
# Macedonia del norte

# %%
#Crea un diccionario `precios` con productos y su precio. 
#Pide al usuario un producto y muestra su precio si existe.
precios = {
    "chorizo": 4.79,
    "morcilla": 2.37,
    "panceta": 4.79,
    "tocino": 1.20,
    "garbanzo": 3.79
}

# %%
#Escribe un programa que cuente cuántas claves tiene un diccionario cualquiera.

# %%
#Crea un diccionario `contacto` y elimina una clave usando `del` o `.pop()`.

# %%
#Usa un bucle `for` para mostrar todas las claves y valores de un 
#diccionario `animal = {'tipo':'perro', 'nombre':'Toby', 'edad':5}`.

# %%
#Crea un diccionario vacío `alumno = {}` y permite al usuario añadir 
#tres pares clave-valor mediante `input()`.

# %%
#Crea un diccionario `notas = {'Juan':7, 'María':9, 'Ana':6}`. Muestra el promedio de las notas.

# %%
#Pide al usuario nombres y edades hasta escribir 'fin'. 
#Guarda los datos en un diccionario. Luego muestra la edad media.

# %%
#Crea un diccionario de palabras en inglés y su traducción al español. 
#Pide al usuario una palabra en inglés y muestra su traducción (o un mensaje si no está).

# %%
#Crea un diccionario de meses con su número de días. 
#Pide al usuario un mes y muestra cuántos días tiene.

# %%
#Dado el diccionario `inventario = {'manzanas':50, 'peras':30, 'naranjas':25}`, 
#pide al usuario un producto y una cantidad vendida, 
#descuéntala y muestra el inventario actualizado.

# %%
#Crea un diccionario `alumno = {'nombre':'Laura','notas':[8,9,7,6]}`. Calcula su nota media.

# %%
#Dado un texto, muestra cuántas veces aparece cada letra usando un diccionario de frecuencias.

# %%
#Combina dos diccionarios `a` y `b` en uno solo llamado `c` usando `update()` o `{**a, **b}`.

# %%
#Crea una lista de diccionarios con los datos de 3 empleados 
#(`nombre`, `salario`, `departamento`). 
#Muestra el salario promedio y filtra los del departamento 'Ventas'.

# %%
#Crea un diccionario anidado que represente un aula y calcula la nota media de sus alumnos.

# %%
#Usa un diccionario para contar cuántas veces aparece cada palabra en una 
#frase introducida por el usuario.

# %%
#Simula una base de datos de usuarios: 
#permite registrar e iniciar sesión comprobando email y contraseña.
