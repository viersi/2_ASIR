# %%
productos = [
    {"id": 0,"nombre": "NvME","precio": 100,"stock": 50},
    {"id": 1,"nombre": "RAM","precio": 120,"stock": 67}
]

pedidos = [
    {}
]

def ft_catalogo():
    for i in productos:
        print(i["nombre"], i["stock"])

def ft_addproducto():
    

def ft_pedido(id, stock):


def ft_ventas():
    
    
#Función principal.    
def ft_menu():
#Esta función se ejecuta indefinidamente hasta que el usuario decide salir.
    ft_catalogo()
    while True:
        if :
        
        else:
            print("Hasta la próxima")
#En este caso usamos return para detener el bucle y salir de la función.
            return

ft_menu()
# Out:
# chorizo 50
# panceta 100

# %%
productos = [
    {"id": 0,"nombre": "chorizo","stock": 50,"precio": 3.79},
    {"id": 1,"nombre": "panceta","stock": 100,"precio": 2.79}
]

for i in productos:
        print(i["nombre"], i["stock"])
# Out:
# chorizo 50
# panceta 100

# %%
productos = [
    {"id": 0,"nombre": "NvME","stock": 50,"precio": 100},
    {"id": 1,"nombre": "RAM","stock": 100,"precio": 67}
]

usr = int(input())

if usr in productos[id]:
    print('ese no bro')
else:
    print('bregale ahi')
# Out:
#  0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       1 productos = [
#       2     {"id": 0,"nombre": "NvME","stock": 50,"precio": 100},
#       3     {"id": 1,"nombre": "RAM","stock": 100,"precio": 67}
#       4 ]
#       6 usr = int(input())
# ----> 8 if usr in productos[id]:
#       9     print('ese no bro')
#      10 else:
#
# TypeError: list indices must be integers or slices, not builtin_function_or_method

# %%
#Prueba funcion añadir
productos = [
    {"id": 0,"nombre": "NvME","precio": 100,"stock": 50},
    {"id": 1,"nombre": "RAM","precio": 120,"stock": 67}
]

nvalid = True
keep = True
idin = input()

while keep and nvalid:

    if idin.lower() == "quit":
        keep = False
    
    for i in productos:
        if int(idin) == i["id"]:
            print("Troliaste puto, proba otro")
            idin = input()
        else:
            print("ese si valio wachin")
            nvalid = False
# Out:
#  0
# Troliaste puto, proba otro
#  1
# Troliaste puto, proba otro
#  2
# ese si valio wachin
# ese si valio wachin
